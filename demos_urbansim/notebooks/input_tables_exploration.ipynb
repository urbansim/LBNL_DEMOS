# %%
import pandas as pd
from pandas import HDFStore

# %%
input_data_bay = HDFStore("../data/custom_mpo_06197001_model_data.h5")
# input_data_austin = HDFStore("../data/custom_mpo_48197301_model_data.h5")

# %%
input_data_bay.keys()
# Out:
# ['/blocks',
#  '/counties',
#  '/ect',
#  '/edges',
#  '/hct',
#  '/household_targets_acs',
#  '/household_validation_acs',
#  '/households',
#  '/job_county_targets_BEA',
#  '/job_county_validation_BEA',
#  '/job_flows',
#  '/job_targets',
#  '/job_validation',
#  '/jobs',
#  '/metadata',
#  '/nodes',
#  '/persons',
#  '/price_targets',
#  '/price_validation',
#  '/residential_units',
#  '/travel_data',
#  '/unit_county_targets_PEP',
#  '/unit_county_validation_PEP',
#  '/unit_targets',
#  '/unit_validation',
#  '/validation_ect',
#  '/validation_hct',
#  '/values']

# %%
input_data_austina["persons"]
# Out:
#            age  earning   edu  hispanic  hours  member_id  race_id  relate  \
# person_id
# 0           29  28000.0  13.0         1   40.0          1        8       0
# 1            5      0.0   4.0         1    0.0          3        8       2
# 2            1      0.0   0.0         1    0.0          4        8       2
# 3           20      0.0  16.0         1    0.0          2        8       1
# 4           22  30000.0  20.0         1   50.0          3        8       2
# ...        ...      ...   ...       ...    ...        ...      ...     ...
# 1676833     57      0.0  16.0         0    0.0          1        9       0
# 1676834     55  48000.0  16.0         0   40.0          1        9       0
# 1676835     58  57000.0  19.0         0   50.0          2        9       1
# 1676836     60      0.0  10.0         1    0.0          1        8       0
# 1676837     33  30000.0  19.0         1   40.0          1        8       0
#
# ...

# %%
input_data_bay.keys()
# Out:
# ['/blocks',
#  '/counties',
#  '/ect',
#  '/edges',
#  '/hct',
#  '/household_targets_acs',
#  '/household_validation_acs',
#  '/households',
#  '/job_county_targets_BEA',
#  '/job_county_validation_BEA',
#  '/job_flows',
#  '/job_targets',
#  '/job_validation',
#  '/jobs',
#  '/metadata',
#  '/nodes',
#  '/persons',
#  '/price_targets',
#  '/price_validation',
#  '/residential_units',
#  '/travel_data',
#  '/unit_county_targets_PEP',
#  '/unit_county_validation_PEP',
#  '/unit_targets',
#  '/unit_validation',
#  '/validation_ect',
#  '/validation_hct',
#  '/values']

# %%
input_data_bay["persons"].columns
# Out:
# Index(['age', 'earning', 'edu', 'hispanic', 'hours', 'member_id', 'race_id',
#        'relate', 'sex', 'student', 'work_at_home', 'worker', 'household_id',
#        'person_age', 'person_sex', 'race', 'hispanic.1', 'p_hispanic', 'MAR'],
#       dtype='object')

# %%
bay_households = input_data_bay["households"]

# %%
bay_households["workers"].unique()
# Out:
# array([ 1.,  0.,  2.,  3.,  4.,  5.,  7.,  6., 13.,  8.,  9., 11., 10.])

# %%
bay_households["hh_workers"].unique()
# Out:
# array(['one', 'none', 'two or more'], dtype=object)

# %%
output_data = HDFStore("../data/model_data_48197301_2018.h5")

# %%
output_data["/2018/blocks"]
# Out:
#                  residential_unit_capacity cousub block_group_id          x  \
# block_id
# 480219504001001                        0.0  90210   480219504001 -97.324794
# 480219504001006                        0.0  90210   480219504001 -97.318834
# 480219504001007                       74.0  90210   480219504001 -97.317766
# 480219504001008                       51.0  90210   480219504001 -97.319772
# 480219504001009                       59.0  90210   480219504001 -97.319185
# ...                                    ...    ...            ...        ...
# 484910210002077                      545.0  93845   484910210002 -97.411820
# 484910212031000                     1492.0  93845   484910212031 -97.396929
# 484910212031001                      261.0  93845   484910212031 -97.383413
# 484910212031004                     1764.0  93845   484910212031 -97.409480
# 484910212031005                       51.0  93845   484910212031 -97.419255
#
# ...
